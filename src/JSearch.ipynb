# %%
import requests
import json

# %%
url = "https://jsearch.p.rapidapi.com/search"

# %%
querystring = {"query":"developer jobs in dehradun","page":"1","num_pages":"1","country":"in","date_posted":"all","job_requirements":"no_experience"}

# %%
headers = {
	"x-rapidapi-key": "75e9647021msh2f86bc8ce0ccdafp1c9592jsned74d1bd6193",
	"x-rapidapi-host": "jsearch.p.rapidapi.com"
}

# %%
response = requests.get(url, headers=headers, params=querystring)

# %%
if response.status_code == 200:
    with open('Jsearch_dataset.json', 'w') as json_file:
        json.dump(response.json(), json_file, indent=4)
    print("Data saved to Jsearch_dataset.json")
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# Data saved to dataset.json

# %%
print(response.json())
# Out:
# {'status': 'OK', 'request_id': '3e535151-6b63-4bf3-8851-d04aee919257', 'parameters': {'query': 'developer jobs in dehradun', 'page': 1, 'num_pages': 1, 'date_posted': 'all', 'job_requirements': ['no_experience'], 'country': 'in', 'language': 'en'}, 'data': [{'job_id': '8dN_CbEpMbb7WLHnAAAAAA==', 'job_title': 'Junior Web Developer (Front-End)', 'employer_name': 'The ConnectHub', 'employer_logo': None, 'employer_website': 'https://theconnecthub.com', 'job_publisher': 'WhatJobs', 'job_employment_type': 'Full–time', 'job_employment_types': ['FULLTIME'], 'job_apply_link': 'https://en-in.whatjobs.com/gfj/123689812?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'job_apply_is_direct': False, 'apply_options': [{'publisher': 'WhatJobs', 'apply_link': 'https://en-in.whatjobs.com/gfj/123689812?utm_campaign=google_jobs_apply&utm_source=google_jobs_apply&utm_medium=organic', 'is_direct': False}], 'job_description': 'Junior Web Developer (Front-End)\n\nLocation: C-Scheme, Jaipur | Job Type: Full-Time, On-Site | Experience: 1–2 Years\n\nAbout the Organisation:\n\nConnectHub is a 15-year-old digital agency that has helped brands like Huawei, Hisense, Toshiba, Dalmia, Cairn, and many others to market their products and solve business problems digitally.\n\nFrom building advanced eCommerce sites to running high-performance advertising campaigns, conversion analytics, and viral content strategies, the ConnectHub team is at the forefront of everything digital.\n\nAbout the Role:\n\nWe are looking for a skilled Junior Web Developer (Front-End) to join our growing development team. The ideal candidate will have 1–2 years of experience in HTML, CSS, PHP, WordPress, Shopify, and Liquid. If you are passionate about web development and want to work on exciting e-commerce and corporate website projects, we would love to connect with you.\n\nResponsibilities:\n\nDevelop and maintain responsive websites using HTML, CSS, and PHP. Build and customize websites on WordPress and Shopify platforms. Work with Shopify’s Liquid template language for front-end development and customization. Collaborate with design and marketing teams to implement website features and designs. Ensure cross-browser compatibility, mobile responsiveness, and performance optimization. Troubleshoot and resolve website issues as they arise. Stay updated with the latest web technologies and industry trends.\n\nRequirements:\n\n1–2 years of professional experience in web development. Strong proficiency in HTML5, CSS3, and basic PHP. Hands-on experience with WordPress theme customization and plugin handling. Hands-on experience with Shopify store setup and Liquid coding for theme customization. Good understanding of responsive and adaptive design. Basic knowledge of SEO principles related to front-end development. Strong attention to detail and ability to deliver high-quality work. Good communication skills to collaborate with internal teams.\n\nAdditional Information:\n\nWork Mode: On-Site (C-Scheme, Jaipur)\n\nCompensation: As per industry standards (based on skills and experience)\n\nHow to Apply:\n\nPlease submit your resume and, if available, links to your portfolio or past projects to\n\nShortlisted candidates will be contacted for technical rounds and interviews.\n\nJoin us and work on diverse and impactful web development projects with a dynamic team!', 'job_is_remote': False, 'job_posted_at': '2 days ago', 'job_posted_at_timestamp': 1745884800, 'job_posted_at_datetime_utc': '2025-04-29T00:00:00.000Z', 'job_location': 'Dehradun, Uttarakhand', 'job_city': 'Dehradun', 'job_state': 'Uttarakhand', 'job_country': 'IN', 'job_latitude': 30.316494499999997, 'job_longitude': 78.03219179999999, 'job_benefits': None, 'job_google_link': 'https://www.google.com/search?q=jobs&gl=in&hl=en&udm=8#vhid=vt%3D20/docid%3D8dN_CbEpMbb7WLHnAAAAAA%3D%3D&vssid=jobs-detail-viewer', 'job_salary': None, 'job_min_salary': None, 'job_max_salary': None, 'job_salary_period': None, 'j ...
